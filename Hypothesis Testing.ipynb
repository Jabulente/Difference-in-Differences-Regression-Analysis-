# %% [markdown]
# <h1 style='font-size: 30px; font-family: Agency FB; font-weight: 700; text-align: center'>Hypothesis Testing</h1>
#
# ---

# %% [markdown]
# <h3 style='font-family: Agency FB; font-size: 20px;  font-weight: 600''>1.0. Import Required Libraries</h3
#                                                                                                           >

# %%
from scipy.stats import shapiro, levene
import matplotlib.pyplot as plt
import scipy.stats as stats  
import seaborn as sns  
import pandas as pd  
import numpy as np 
import math
import re

import warnings  
warnings.simplefilter("ignore")  
pd.set_option('display.max_columns', 10) 
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# <h3 style='font-family: Agency FB; font-size: 20px;  font-weight: 600''>2.0. Load and Inspect Dataset</h3>

# %%
DATA_PATH = "./Datasets/Marketing Campaign Dataset.csv"
full_data = pd.read_csv(DATA_PATH)
display(full_data)
# Out:
#       Store_ID        Date  Month Index Store Size  \
# 0            1  2023-01-01            1      Small
# 1            1  2023-02-01            2      Small
# 2            1  2023-03-01            3      Small
# 3            1  2023-04-01            4      Small
# 4            1  2023-05-01            5      Small
# ...        ...         ...          ...        ...
# 2995       100  2025-02-01           26     Medium
# 2996       100  2025-03-01           27     Medium
# 2997       100  2025-04-01           28     Medium
# 2998       100  2025-05-01           29     Medium
# 2999       100  2025-06-01           30     Medium
#
#                    Marketing Strategy  Average Order Values (Tsh)  \
# 0                Pilot Launch Regions                       31398
# 1                Pilot Launch Regions                       31398
# 2                Pilot Launch Regions                       31398
# 3                Pilot Launch Regions                       31398
# 4                Pilot Launch Regions                       31398
# ...                               ...                         ...
# 2995  Business-as-Usual (BAU) Regions                       37190
# 2996  Business-as-Usual (BAU) Regions                       37190
# 2997  Business-as-Usual (BAU) Regions                       37190
# 2998  Business-as-Usual (BAU) Regions                       37190
# 2999  Business-as-Usual (BAU) Regions                       37190
#
#       Post Campaign Period  Sales Revenue (Tsh)
# 0                        0           1038101.58
# 1                        0            859521.34
# 2                        0            921424.44
# 3                        0            899762.87
# 4                        0           1072438.54
# ...                    ...                  ...
# 2995                     1           1594221.19
# 2996                     1           1330848.99
# 2997                     1           1535028.72
# 2998                     1           1601262.58
# 2999                     1           1480954.92
#
# [3000 rows x 8 columns]

# %%
full_data['Date'] = pd.to_datetime(full_data['Date'])
event_date = full_data['Date'].min() + pd.DateOffset(months=18)
df = full_data[full_data['Date'] < event_date]
display(df)
# Out:
#       Store_ID       Date  Month Index Store Size  \
# 0            1 2023-01-01            1      Small
# 1            1 2023-02-01            2      Small
# 2            1 2023-03-01            3      Small
# 3            1 2023-04-01            4      Small
# 4            1 2023-05-01            5      Small
# ...        ...        ...          ...        ...
# 2983       100 2024-02-01           14     Medium
# 2984       100 2024-03-01           15     Medium
# 2985       100 2024-04-01           16     Medium
# 2986       100 2024-05-01           17     Medium
# 2987       100 2024-06-01           18     Medium
#
#                    Marketing Strategy  Average Order Values (Tsh)  \
# 0                Pilot Launch Regions                       31398
# 1                Pilot Launch Regions                       31398
# 2                Pilot Launch Regions                       31398
# 3                Pilot Launch Regions                       31398
# 4                Pilot Launch Regions                       31398
# ...                               ...                         ...
# 2983  Business-as-Usual (BAU) Regions                       37190
# 2984  Business-as-Usual (BAU) Regions                       37190
# 2985  Business-as-Usual (BAU) Regions                       37190
# 2986  Business-as-Usual (BAU) Regions                       37190
# 2987  Business-as-Usual (BAU) Regions                       37190
#
#       Post Campaign Period  Sales Revenue (Tsh)
# 0                        0           1038101.58
# 1                        0            859521.34
# 2                        0            921424.44
# 3                        0            899762.87
# 4                        0           1072438.54
# ...                    ...                  ...
# 2983                     0           1385822.26
# 2984                     0           1352717.41
# 2985                     0           1372174.06
# 2986                     0           1383435.11
# 2987                     0           1317516.66
#
# [1800 rows x 8 columns]

# %% [markdown]
# <h3 style='font-family: Agency FB; font-size: 20px; font-weight: 600'>3.0: Homogeneity of Variance (Levene's Test)</h3>

# %%
def Levene_test(df, variables=None, groups=None): 
    if variables is None:
        variables = df.select_dtypes(include=['number']).columns.tolist()
        for g in groups:
            if g in variables:
                variables.remove(g)
    
    results = []
    for group in groups:
        for variable in variables:
            grouped_data = [g[variable].dropna().values for _, g in df.groupby(group)]
            if all(len(g) > 1 for g in grouped_data):  # Ensure each group has enough data
                levene_stat, levene_p = levene(*grouped_data)
                interpretation = 'Homogeneous' if levene_p > 0.05 else 'Not Homogeneous'
                
            else:
                levene_stat, levene_p, interpretation = None, None, 'Insufficient data'
            
            results.append({
                'Category': group,
                'Variable': variable,
                'Test Statistic': levene_stat,
                'P-Value': levene_p,
                'Interpretation': interpretation
            })
    
    return pd.DataFrame(results)
variables = ["Average Order Values (Tsh)", "Sales Revenue (Tsh)"]
result_df = Levene_test(df, variables, groups=["Store Size", "Marketing Strategy"])
display(result_df)
# Out:
#              Category                    Variable  Test Statistic  P-Value  \
# 0          Store Size  Average Order Values (Tsh)           19.74     0.00
# 1          Store Size         Sales Revenue (Tsh)            0.56     0.57
# 2  Marketing Strategy  Average Order Values (Tsh)            2.34     0.13
# 3  Marketing Strategy         Sales Revenue (Tsh)           32.72     0.00
#
#     Interpretation
# 0  Not Homogeneous
# 1      Homogeneous
# 2      Homogeneous
# 3  Not Homogeneous

# %% [markdown]
# <h3 style='font-family: Agency FB; font-size: 20px; font-weight: 600'>4.0: Normality Test (Shapiro Wilk Test)</h3>

# %%
def bootstrapping(df, column, num_samples=1000, sample_size=30):
    sample_means = []
    for _ in range(num_samples):
        sample = df[column].dropna().sample(n=sample_size, replace=True)
        sample_means.append(sample.mean())
    return sample_means

def shapiro_wilk_test(df, group_cols, numeric_cols=None, use_bootstrap=True, num_samples=1000, sample_size=30): 
    if numeric_cols is None:
        numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
  
    results = []
    for group_col in group_cols:
        for group, group_df in df.groupby(group_col):
            for col in numeric_cols:
                if use_bootstrap: data = bootstrapping(group_df, col, num_samples=num_samples, sample_size=sample_size)
                else:
                    data = group_df[col].dropna()
                    
                if len(data) >= 3:
                    stat, p_value = shapiro(data)
                    interpretation = 'Normal' if p_value > 0.05 else 'Not Normal'
                else:
                    stat, p_value, interpretation = None, None, 'Insufficient data'
                
                results.append({
                    'Category': group_col,
                    'Group': group,
                    'Variable': col,
                    'Test Statistic': stat,
                    'P-Value': p_value,
                    'Interpretation': interpretation,
                    'Used Bootstrap': use_bootstrap
                })
        
    results_df = pd.DataFrame(results)
    return results_df

result_df = shapiro_wilk_test(df, group_cols=["Store Size", "Marketing Strategy"], use_bootstrap=True)
display(result_df)
# Out:
#               Category                            Group  \
# 0           Store Size                            Large
# 1           Store Size                            Large
# 2           Store Size                            Large
# 3           Store Size                            Large
# 4           Store Size                            Large
# 5           Store Size                           Medium
# 6           Store Size                           Medium
# 7           Store Size                           Medium
# 8           Store Size                           Medium
# 9           Store Size                           Medium
# 10          Store Size                            Small
# 11          Store Size                            Small
# 12          Store Size                            Small
# 13          Store Size                            Small
# 14          Store Size                            Small
# 15  Marketing Strategy  Business-as-Usual (BAU) Regions
# 16  Marketing Strategy  Business-as-Usual (BAU) Regions
# 17  Marketing Strategy  Business-as-Usual (BAU) Regions
# 18  Marketing Strategy  Business-as-Usual (BAU) Regions
# 19  Marketing Strategy  Business-as-Usual (BAU) Regions
# 20  Marketing Strategy             Pilot Launch Regions
# 21  Marketing Strategy             Pilot Launch Regions
# 22  Marketing Strategy             Pilot Launch Regions
# 23  Marketing Strategy             Pilot Launch Regions
# 24  Marketing Strategy             Pilot Launch Regions
#
#                       Variable  Test Statistic  P-Value Interpretation  \
# 0                     Store_ID            1.00     0.40         Normal
# 1                  Month Index            1.00     0.14         Normal
# 2   Average Order Values (Tsh)            1.00     0.29         Normal
# 3         Post Campaign Period            1.00     1.00         Normal
# 4          Sales Revenue (Tsh)            1.00     0.70         Normal
# 5                     Store_ID            1.00     0.72         Normal
# 6                  Month Index            1.00     0.61         Normal
# 7   Average Order Values (Tsh)            1.00     0.63         Normal
# 8         Post Campaign Period            1.00     1.00         Normal
# 9          Sales Revenue (Tsh)            1.00     0.05         Normal
# 10                    Store_ID            1.00     0.74         Normal
# 11                 Month Index            1.00     0.12         Normal
# 12  Average Order Values (Tsh)            1.00     0.45         Normal
# 13        Post Campaign Period            1.00     1.00         Normal
# 14         Sales Revenue (Tsh)            1.00     0.78         Normal
# 15                    Store_ID            1.00     0.12         Normal
# 16                 Month Index            1.00     0.71         Normal
# 17  Average Order Values (Tsh)            1.00     0.74         Normal
# 18        Post Campaign Period            1.00     1.00         Normal
# 19         Sales Revenue (Tsh)            1.00     0.31         Normal
# 20                    Store_ID            1.00     0.22         Normal
# 21                 Month Index            1.00     0.04     Not Normal
# 22  Average Order Values (Tsh)            1.00     0.46         Normal
# 23        Post Campaign Period            1.00     1.00         Normal
# 24         Sales Revenue (Tsh)            1.00     0.26         Normal
#
#     Used Bootstrap
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21            True
# 22            True
# 23            True
# 24            True

# %%
result_df = shapiro_wilk_test(df, group_cols=["Store Size", "Marketing Strategy"], use_bootstrap=False)
display(result_df)
# Out:
#               Category                            Group  \
# 0           Store Size                            Large
# 1           Store Size                            Large
# 2           Store Size                            Large
# 3           Store Size                            Large
# 4           Store Size                            Large
# 5           Store Size                           Medium
# 6           Store Size                           Medium
# 7           Store Size                           Medium
# 8           Store Size                           Medium
# 9           Store Size                           Medium
# 10          Store Size                            Small
# 11          Store Size                            Small
# 12          Store Size                            Small
# 13          Store Size                            Small
# 14          Store Size                            Small
# 15  Marketing Strategy  Business-as-Usual (BAU) Regions
# 16  Marketing Strategy  Business-as-Usual (BAU) Regions
# 17  Marketing Strategy  Business-as-Usual (BAU) Regions
# 18  Marketing Strategy  Business-as-Usual (BAU) Regions
# 19  Marketing Strategy  Business-as-Usual (BAU) Regions
# 20  Marketing Strategy             Pilot Launch Regions
# 21  Marketing Strategy             Pilot Launch Regions
# 22  Marketing Strategy             Pilot Launch Regions
# 23  Marketing Strategy             Pilot Launch Regions
# 24  Marketing Strategy             Pilot Launch Regions
#
#                       Variable  Test Statistic  P-Value Interpretation  \
# 0                     Store_ID            0.91     0.00     Not Normal
# 1                  Month Index            0.95     0.00     Not Normal
# 2   Average Order Values (Tsh)            0.86     0.00     Not Normal
# 3         Post Campaign Period            1.00     1.00         Normal
# 4          Sales Revenue (Tsh)            1.00     0.91         Normal
# 5                     Store_ID            0.93     0.00     Not Normal
# 6                  Month Index            0.95     0.00     Not Normal
# 7   Average Order Values (Tsh)            0.96     0.00     Not Normal
# 8         Post Campaign Period            1.00     1.00         Normal
# 9          Sales Revenue (Tsh)            1.00     0.61         Normal
# 10                    Store_ID            0.97     0.00     Not Normal
# 11                 Month Index            0.95     0.00     Not Normal
# 12  Average Order Values (Tsh)            0.96     0.00     Not Normal
# 13        Post Campaign Period            1.00     1.00         Normal
# 14         Sales Revenue (Tsh)            1.00     0.21         Normal
# 15                    Store_ID            0.96     0.00     Not Normal
# 16                 Month Index            0.95     0.00     Not Normal
# 17  Average Order Values (Tsh)            0.97     0.00     Not Normal
# 18        Post Campaign Period            1.00     1.00         Normal
# 19         Sales Revenue (Tsh)            0.98     0.00     Not Normal
# 20                    Store_ID            0.94     0.00     Not Normal
# 21                 Month Index            0.95     0.00     Not Normal
# 22  Average Order Values (Tsh)            0.96     0.00     Not Normal
# 23        Post Campaign Period            1.00     1.00         Normal
# 24         Sales Revenue (Tsh)            0.96     0.00     Not Normal
#
#     Used Bootstrap
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 5            False
# 6            False
# 7            False
# 8            False
# 9            False
# 10           False
# 11           False
# 12           False
# 13           False
# 14           False
# 15           False
# 16           False
# 17           False
# 18           False
# 19           False
# 20           False
# 21           False
# 22           False
# 23           False
# 24           False

# %% [markdown]
# <h3 style='font-family: Agency FB; font-size: 20px; font-weight: 600'>5.0: One Way  Analysis of Varience</h3>

# %%
from statsmodels.formula.api import ols as smf_ols 
from statsmodels.stats.anova import anova_lm  
from statsmodels.formula.api import ols
import statsmodels.formula.api as smf 
import statsmodels.api as sm  

def rename(text): return re.sub(r'[^a-zA-Z]', "_", text)

def One_way_anova(data, dependent_ariables, Independents_variables):
    results = []
    Independents_variables = [rename(col) for col in Independents_variables]
    data = data.rename(columns={col: rename(col) for col in data.columns})
    for Independents_variable in Independents_variables:
        for col in dependent_ariables:
            column_name = rename(col)  
            formula = f"{column_name} ~ C({Independents_variable})" 
            model = smf.ols(formula, data=data).fit()
            anova_table = sm.stats.anova_lm(model, typ=2)
            for source, row in anova_table.iterrows():
                p_value = row["PR(>F)"]
                interpretation = "Significant" if p_value < 0.05 else "No significant"
                if source == "Residual": interpretation = "-"
        
                results.append({
                    "Variable": col,
                    "Factor": Independents_variable.title(),
                    "Source": source,
                    "Sum Sq": row["sum_sq"],
                    "df": row["df"],
                    "F-Value": row["F"],
                    "p-Value": p_value,
                    "Interpretation": interpretation
                })

    return pd.DataFrame(results)

Independents_variables = ["Store Size", "Marketing Strategy"]
dependent_ariables = ["Average Order Values (Tsh)", "Sales Revenue (Tsh)"]
anova_results = One_way_anova(df, dependent_ariables, Independents_variables)
anova_results
# Out:
#                      Variable              Factor                 Source  \
# 0  Average Order Values (Tsh)          Store_Size          C(Store_Size)
# 1  Average Order Values (Tsh)          Store_Size               Residual
# 2         Sales Revenue (Tsh)          Store_Size          C(Store_Size)
# 3         Sales Revenue (Tsh)          Store_Size               Residual
# 4  Average Order Values (Tsh)  Marketing_Strategy  C(Marketing_Strategy)
# 5  Average Order Values (Tsh)  Marketing_Strategy               Residual
# 6         Sales Revenue (Tsh)  Marketing_Strategy  C(Marketing_Strategy)
# 7         Sales Revenue (Tsh)  Marketing_Strategy               Residual
#
#               Sum Sq      df  F-Value  p-Value  Interpretation
# 0       106487361.20    2.00     2.12     0.12  No significant
# 1     45090293944.48 1797.00      NaN      NaN               -
# 2  86935849314370.72    2.00  4536.89     0.00     Significant
# 3  17217039246938.81 1797.00      NaN      NaN               -
# 4      1920908954.88    1.00    79.81     0.00     Significant
# 5     43275872350.80 1798.00      NaN      NaN               -
# 6    408612612824.55    1.00     7.08     0.01     Significant
# 7 103744275948484.53 1798.00      NaN      NaN               -

# %% [markdown]
# <h2 style='font-size: 20px; font-family: Agency FB; font-weight: 600'>6.0: Welch's ANOVA (Welch's F test)</h2>

# %%
import pingouin as pg

def welchs_anova(data, dependent_variables, Independent_variables):
    results = []
    
    Independent_variables = [rename(col) for col in Independent_variables]
    data = data.rename(columns={col: rename(col) for col in data.columns})
    for group in Independent_variables:
        for col in dependent_variables:
            column_name = rename(col)
            
            aov = pg.welch_anova(data=data, dv=column_name, between=group)
            for _, row in aov.iterrows():
                p_value = row["p-unc"]
                interpretation = "Significant" if p_value < 0.05 else "Not Significant"
                results.append({
                    "Variable": col,
                    "Grouping Factor": group.title(),
                    "Source": row["Source"],
                    "df": row["ddof1"],
                    "F-Value": row["F"],
                    "p-Value": p_value,
                    "Significance": interpretation
                })

    return pd.DataFrame(results)

Independent_variables = ["Store Size", "Marketing Strategy"]
dependent_variables = ["Average Order Values (Tsh)", "Sales Revenue (Tsh)"]
welch_results = welchs_anova(df, dependent_variables, Independent_variables)
welch_results
# Out:
#                      Variable     Grouping Factor              Source  df  \
# 0  Average Order Values (Tsh)          Store_Size          Store_Size   2
# 1         Sales Revenue (Tsh)          Store_Size          Store_Size   2
# 2  Average Order Values (Tsh)  Marketing_Strategy  Marketing_Strategy   1
# 3         Sales Revenue (Tsh)  Marketing_Strategy  Marketing_Strategy   1
#
#    F-Value  p-Value     Significance
# 0     1.85     0.16  Not Significant
# 1  4558.85     0.00      Significant
# 2    79.81     0.00      Significant
# 3     7.08     0.01      Significant

# %% [markdown]
# <h2 style='font-size: 20px; font-family: Agency FB; font-weight: 600'>7.0: Kruskal-Wallis Test</h2>

# %%
from scipy.stats import kruskal

def kruskall_wallis(df, independent_variables: str, dependent_variables: list = None):
    if dependent_variables is None:
        dependent_variables = df.select_dtypes(include=[np.number]).columns.tolist()
        for g in independent_variables:
            if g in dependent_variables:
                dependent_variables.remove(g)
    results = []
    for group_column in independent_variables:
        for column in dependent_variables:
            groups = [group[column].dropna().values for name, group in df.groupby(group_column)]
            stats, p_value = kruskal(*groups)
            interpretation = 'Significant' if p_value < 0.05 else 'Not Significant'
            results.append({
                'Group': group_column,
                'Variables': column,
                'Kruskal-Wallis Statistic': stats,
                'P-value': p_value,
                'Significant (α<0.05)': interpretation
            })
    return pd.DataFrame(results)

independent_variables = ["Store Size", "Marketing Strategy"] 
dependent_variables = ["Average Order Values (Tsh)", "Sales Revenue (Tsh)"]
results = kruskall_wallis(df, independent_variables, dependent_variables)
display(results)
# Out:
#                 Group                   Variables  Kruskal-Wallis Statistic  \
# 0          Store Size  Average Order Values (Tsh)                      4.39
# 1          Store Size         Sales Revenue (Tsh)                   1437.47
# 2  Marketing Strategy  Average Order Values (Tsh)                     60.65
# 3  Marketing Strategy         Sales Revenue (Tsh)                      1.95
#
#    P-value Significant (α<0.05)
# 0     0.11      Not Significant
# 1     0.00          Significant
# 2     0.00          Significant
# 3     0.16      Not Significant

# %% [markdown]
# <h2 style='font-family: Agency FB; font-size: 20px; font-weight: 600'>8.0: Tukey's Honest Significant Difference (THSD)</h2>

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd  

def Turkey_results(df, variables, group_cols):
    results_data = []
    for group in group_cols:
        for metric in variables:
            turkey_results = pairwise_tukeyhsd(endog=df[metric], groups=df[group], alpha=0.05)
            results_table = turkey_results.summary()
            
            for i in range(1, len(results_table)):
                row = results_table.data[i]
                results_data.append({
                    'group': group,
                    'Metric': metric,
                    'Group1': row[0],
                    'Group2': row[1],
                    'Mean Difference': row[2],
                    'P-Value': row[3],
                    'Lower CI': row[4],
                    'Upper CI': row[5],
                    'Reject Null': row[6]
                })
        
        result_df = pd.DataFrame(results_data)
    return result_df

group_cols = ["Store Size", "Marketing Strategy"] 
variables = ["Average Order Values (Tsh)", "Sales Revenue (Tsh)"]
results = Turkey_results(df, variables, group_cols = group_cols)
results
# Out:
#                 group                      Metric  \
# 0          Store Size  Average Order Values (Tsh)
# 1          Store Size  Average Order Values (Tsh)
# 2          Store Size  Average Order Values (Tsh)
# 3          Store Size         Sales Revenue (Tsh)
# 4          Store Size         Sales Revenue (Tsh)
# 5          Store Size         Sales Revenue (Tsh)
# 6  Marketing Strategy  Average Order Values (Tsh)
# 7  Marketing Strategy         Sales Revenue (Tsh)
#
#                             Group1                Group2  Mean Difference  \
# 0                            Large                Medium           742.21
# 1                            Large                 Small           695.92
# 2                           Medium                 Small           -46.28
# 3                            Large                Medium       -371103.76
# 4                            Large                 Small       -666105.63
# 5                           Medium                 Small       -295001.87
# 6  Business-as-Usual (BAU) Regions  Pilot Launch Regions         -2066.08
# 7  Business-as-Usual (BAU) Regions  Pilot Launch Regions         30133.50
#
#    P-Value   Lower CI   Upper CI  Reject Null
# 0     0.11    -127.69    1612.11        False
# 1     0.15    -185.59    1577.43        False
# 2     0.98    -641.10     548.53        False
# 3     0.00 -388102.13 -354105.40         True
# 4     0.00 -683330.86 -648880.40         True
# 5     0.00 -306624.93 -283378.80         True
# 6     0.00   -2519.67   -1612.49         True
# 7     0.01    7924.89   52342.12         True

# %% [markdown]
# ---
#
# This analysis was performed by **Jabulente**, a passionate and dedicated data analyst with a strong commitment to using data to drive meaningful insights and solutions. For inquiries, collaborations, or further discussions, please feel free to reach out via.
#
# ----
#
# <div align="center">
#
# [![GitHub](https://img.shields.io/badge/GitHub-Jabulente-black?logo=github)](https://github.com/Jabulente)  [![LinkedIn](https://img.shields.io/badge/LinkedIn-Jabulente-blue?logo=linkedin)](https://linkedin.com/in/jabulente-208019349)  [![Email](https://img.shields.io/badge/Email-jabulente@hotmail.com-red?logo=gmail)](mailto:Jabulente@hotmail.com)
#
# </div>
#
#
# <h1 style='font-size: 35px; color: red; font-family: Agency FB; font-weight: 700; text-align: center'>Data to Drive Meaningful Insights and Solutions</h1>
